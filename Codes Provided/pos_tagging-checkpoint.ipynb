# %% [markdown]
# PoS tagging is done using a transformer model trained particularly on the Egyptian Arabic dialect. The model is called [CAMeL-Lab/bert-base-arabic-camelbert-ca-pos-egy](https://huggingface.co/CAMeL-Lab/bert-base-arabic-camelbert-ca-pos-egy)

# %%
#import torch
import pandas as pd
import numpy as np

from tqdm import tqdm

# %%
from transformers import pipeline

#from transformers import BertModel
# from camel_tools.disambig.mle import MLEDisambiguator
# from camel_tools.tagger.default import DefaultTagger

# %%
songs = pd.read_csv(
    "./Tamer_Hosny_final.csv",
    dtype = {"Year": str}
)
print("Number of songs: ", len(songs))
# Out:
# Number of songs:  140

# %%
songs.sample(20)
# Out:
#                                       Title  Song ID
# 122                        Teaarafy - تعرفي  9400613  \
# 115       Sehiet Ala Sotha - صحيت على صوتها  8818025
# 37            Elly Gai Ahla - اللي جاي أحلى  7247444
# 129                Ya3ny Khalas - يعني خلاص  7354633
# 132            Ya Bent El Eh - يا بنت الإيه  8801134
# 5                    Afalt Alby - قفلت قلبي  8992648
# 128              We Enta Maaya - وإنت معايا  3852503
# 9    Allah Yebarekly Fek - الله يباركلي فيك  2225766
# 38                      El Wahida - الوحيدة  7354629
# 103              Nasseeny Leih - ناسيني ليه  3852496
# 47                         Erga3ly - إرجعلي  7394172
# 80         Kol Dah Ala Aieh - كل ده على إيه  8894490
# 75              Kan Fe Wahda - كان في واحدة  8850946
# 73              Kammel Lewahdak - كمل لوحدك  8960913
# 63                Hases Bekhouf - حاسس بخوف  8910506
# 91      Mahadesh Hases Beya - محدش حاسس بيا  9399046
# 51             Etla3 Men Doul - إطلع من دول  7354634
# 69                                 Hob - حب  8836938
# 45     Enty Nesity Nafsek - إنتي نسيتي نفسك  8991346
# 85      Lama Betkon Ba’eid - لما بتكون بعيد  8991345
#
#                                                    URL
# 122     https://genius.com/Tamer-hosny-teaarafy-lyrics  \
# 115  https://genius.com/Tamer-hosny-sehiet-ala-soth...
# 37   https://genius.com/Tamer-hosny-elly-gai-ahla-l...
# 129  https://genius.com/Tamer-hosny-ya3ny-khalas-ly...
# 132  https://genius.com/Tamer-hosny-ya-bent-el-eh-l...
# 5     https://genius.com/Tamer-hosny-afalt-alby-lyrics
# 128  https://genius.com/Tamer-hosny-we-enta-maaya-l...
# 9    https://genius.com/Tamer-hosny-allah-yebarekly...
# 38     https://genius.com/Tamer-hosny-el-wahida-lyrics
# 103  https://genius.com/Tamer-hosny-nasseeny-leih-l...
# 47       https://genius.com/Tamer-hosny-erga3ly-lyrics
# 80   https://genius.com/Tamer-hosny-kol-dah-ala-aie...
# 75   https://genius.com/Tamer-hosny-kan-fe-wahda-ly...
# 73   https://genius.com/Tamer-hosny-kammel-lewahdak...
# 63   https://genius.com/Tamer-hosny-hases-bekhouf-l...
# 91   https://genius.com/Tamer-hosny-mahadesh-hases-...
# 51   https://genius.com/Tamer-hosny-etla3-men-doul-...
# 69           https://genius.com/Tamer-hosny-hob-lyrics
# 45   https://genius.com/Tamer-hosny-enty-nesity-naf...
# 85   https://genius.com/Tamer-hosny-lama-betkon-bae...
#
#                                                 Lyrics Duration
# 122  تعرفي بحلم إيه دلوقتي، تعرفي بحلم إيه؟\nبحلم ي...    03:57  \
# 115  أنا النهاردة صحيت على صوتها\nالله على ده صوت\n...    03:48
# 37   السنة دي عدت علينا صعبة، صعبة أوي\nبس المهم إن...    05:15
# 129  أنا عارف إنك عايز تسيبني\nسيبني وما تجملش الكل...    04:39
# 132  لا لا-لا-لا لا\nلا لا-لا-لا لا\nلا لا-لا-لا لا...    04:11
# 5    أنا لو عيني تشوف غيرك أنا مش هفتحها\nوأي كلمة ...    04:32
# 128  [مقدمة: خالد و\nتامر حسني\n]\nVas-y Tamer\nحبي...    04:06
# 9    يا حبيبي من حبي فيك\nلا هتكلم ولا أغنيلك\nمن ا...    04:04
# 38   الوحيدة اللي أنا حبيتها من كل قلبي بجد\nلا عمر...    04:22
# 103  أنا ما أقدرش أبعد ثانية\nأنا بعدك ماليش في الد...    04:10
# 47   حبيبي أنا قلبي واجعني\nإنت عامل فيا إيه؟\nإنت ...    03:51
# 80   إسمع مني يا قلبي حبيبنا أهو سابنا\nوبيرتاح في ...    04:55
# 75   كان في واحدة حياتها عادية وكان نفسها تتحب\nقاب...    03:52
# 73   ولا هصدق حاجة تقولهالي مهما تعيد وتزيد\nمين ال...    03:48
# 63   حاسس بخوف عمال بيبعد قلبي عنك\nمعرفش ليه مابقت...    04:39
# 91   ما حدش عارف حاجة، ما حدش حاسس بيا\nأيوة ببقى ف...    05:09
# 51   ليه قولي ليه\nقلبي حب ورق ليه\nوإنت قلبك ليه م...    02:46
# 69   حب كان فين الحب قبل ما أهواك\nبكرة مش عايز بكر...    04:39
# 45   إنتي نسيتي نفسك وبقيتي بتجرحيني\nزمان كان بس ن...    03:52
# 85   لما بتكون بعيد بحضر كلام أقوله\nوأما بتكون قري...    04:15
#
#                     Lyricist       Composer              Distribution
# 122          محمد عبد الجابر      محمد رحيم                 عصمت وجيه  \
# 115               أمير طعيمة   عزيز الشافعي           وسام عبد المنعم
# 37                 تامر حسني      تامر حسني           كريم عبد الوهاب
# 129                تامر حسني      تامر حسني                 طارق حسيب
# 132                تامر حسني      تامر حسني                أمير محروس
# 5                  تامر حسني    محمد الصاوي                محمد زقزوق
# 128                تامر حسني      تامر حسني             جلال الحمداوي
# 9                  تامر حسني      تامر حسني                 أحمد عادل
# 38   أشرف الألفي، وتامر حسني      تامر حسني                 مجدي داود
# 103                تامر حسين       تامر علي           وسام عبد المنعم
# 47                 تامر حسني      تامر حسني                      تميم
# 80                أمير طعيمة       شريف بدر                شريف مكاوي
# 75                 سلامة علي       محمد يحي                      تميم
# 73                محمد مصطفى      أحمد محيي                 مدحت خميس
# 63                 محمد حامد       تامر علي              أحمد ابراهيم
# 91                 تامر حسني      تامر حسني                      تميم
# 51           عبد العزيز عمار  حسام البجيرمي                 أحمد عادل
# 69                 نصر محروس       وليد سعد  يحيى الموجي، وأمير محروس
# 45                  حسن عطية       وليد سعد                محمد مصطفى
# 85                 تامر حسني      تامر حسني                محمد مصطفى
#
#                                         Cleaned Lyrics
# 122  تعرفي بحلم ايه دلوقتي تعرفي بحلم ايه بحلم يكون...  \
# 115  انا النهارده صحيت علي صوتها الله علي ده صوت ده...
# 37   السنه دي عدت علينا صعبه صعبه اوي بس المهم اننا...
# 129  انا عارف انك عايز تسيبني سيبني وما تجملش الكلا...
# 132  لا لالالا لا لا لالالا لا لا لالالا لا لالالال...
# 5    انا لو عيني تشوف غيرك انا مش هفتحها واي كلمه ح...
# 128  مقدمه خالد و تامر حسني Vasy Tamer حبيبي خالد Y...
# 9    يا حبيبي من حبي فيك لا هتكلم ولا اغنيلك من الي...
# 38   الوحيده اللي انا حبيتها من كل قلبي بجد لا عمري...
# 103  انا ما اقدرش ابعد ثانيه انا بعدك ماليش في الدن...
# 47   حبيبي انا قلبي واجعني انت عامل فيا ايه انت ساح...
# 80   اسمع مني يا قلبي حبيبنا اهو سابنا وبيرتاح في ع...
# 75   كان في واحده حياتها عاديه وكان نفسها تتحب قابل...
# 73   ولا هصدق حاجه تقولهالي مهما تعيد وتزيد مين الل...
# 63   حاسس بخوف عمال بيبعد قلبي عنك معرفش ليه مابقتش...
# 91   ما حدش عارف حاجه ما حدش حاسس بيا ايوه ببقي في ...
# 51   ليه قولي ليه قلبي حب ورق ليه وانت قلبك ليه ما ...
# 69   حب كان فين الحب قبل ما اهواك بكره مش عايز بكره...
# 45   انتي نسيتي نفسك وبقيتي بتجرحيني زمان كان بس نف...
# 85   لما بتكون بعيد بحضر كلام اقوله واما بتكون قريب...
#
#                                    Tokens No Stopwords Composer_first_name
# 122  تعرفي بحلم ايه دلوقتي تعرفي بحلم ايه بحلم يكون...                محمد  \
# 115  انا النهارده صحيت علي صوتها الله علي ده صوت ده...                عزيز
# 37   السنه دي عدت علينا صعبه صعبه اوي المهم اننا ال...                تامر
# 129  انا عارف انك عايز تسيبني سيبني تجملش الكلام وح...                تامر
# 132  لالالا لالالا لالالا لالالالا One two لالالا ل...                تامر
# 5    انا عيني تشوف غيرك انا مش هفتحها واي كلمه حلوه...                محمد
# 128  مقدمه خالد تامر حسني Vasy Tamer حبيبي خالد Yo ...                تامر
# 9    حبيبي حبي فيك هتكلم اغنيلك اليوم ده هحبك حب جد...                تامر
# 38   الوحيده اللي انا حبيتها قلبي بجد عمري شكيت غير...                تامر
# 103  انا اقدرش ابعد ثانيه انا بعدك ماليش الدنيا اول...                تامر
# 47   حبيبي انا قلبي واجعني انت عامل فيا ايه انت ساح...                تامر
# 80   اسمع مني قلبي حبيبنا اهو سابنا وبيرتاح عذابنا ...                شريف
# 75   واحده حياتها عاديه وكان نفسها تتحب قابلت كلامه...                محمد
# 73   هصدق حاجه تقولهالي تعيد وتزيد مين اللي يضمنلي ...                احمد
# 63   حاسس بخوف عمال بيبعد قلبي عنك معرفش ليه مابقتش...                تامر
# 91   حدش عارف حاجه حدش حاسس بيا ايوه ببقي وسط الناس...                تامر
# 51   ليه قولي ليه قلبي حب ورق ليه وانت قلبك ليه دق ...                حسام
# 69   حب فين الحب اهواك بكره مش عايز بكره الا وانا و...                وليد
# 45   انتي نسيتي نفسك وبقيتي بتجرحيني زمان نفسك اعدي...                وليد
# 85   بتكون بعيد بحضر كلام اقوله واما بتكون قريب بتن...                تامر
#
#     Composer_last_name Lyricist_first_name Lyricist_last_name  Lyrics Length
# 122               رحيم                محمد         عبد الجابر            150  \
# 115            الشافعي                امير              طعيمه            249
# 37                حسني                تامر               حسني            203
# 129               حسني                تامر               حسني            142
# 132               حسني                تامر               حسني            342
# 5               الصاوي                تامر               حسني            128
# 128               حسني                تامر               حسني            331
# 9                 حسني                تامر               حسني            185
# 38                حسني                اشرف  الالفي وتامر حسني            263
# 103                علي                تامر               حسين            191
# 47                حسني                تامر               حسني            173
# 80                 بدر                امير              طعيمه            227
# 75                 يحي               سلامه                علي            173
# 73                محيي                محمد              مصطفي            201
# 63                 علي                محمد               حامد            192
# 91                حسني                تامر               حسني            191
# 51            البجيرمي                 عبد        العزيز عمار            197
# 69                 سعد                 نصر              محروس            165
# 45                 سعد                 حسن               عطيه            214
# 85                حسني                تامر               حسني            203
#
#      Release Year
# 122          2012
# 115          2010
# 37           2011
# 129          2006
# 132          2007
# 5            2010
# 128          2018
# 9            2007
# 38           2006
# 103          2018
# 47           2007
# 80           2014
# 75           2016
# 73           2011
# 63           2007
# 91           2007
# 51           2006
# 69           2004
# 45           2004
# 85           2004

# %%
lyrics = songs[["Title", "Lyrics"]]
lyrics.reset_index()
lyrics = lyrics.dropna()

# %%
print("Number of songs after removing empty lyrics: ", len(lyrics))
# Out:
# Number of songs after removing empty lyrics:  140

# %%
def get_max_lyrics_len():
    """
    Returns the size of the largest song.
    """
    
    return max([len(ly) for ly in lyrics["Lyrics"]])

# %%
L = get_max_lyrics_len()
print("Longest lyrics: ", L)
# Out:
# Longest lyrics:  2443

# %%
pos = pipeline(
    "token-classification", 
    model = "CAMeL-Lab/bert-base-arabic-camelbert-ca-pos-egy",
    device=0
)
# Out:
# Some weights of the model checkpoint at CAMeL-Lab/bert-base-arabic-camelbert-ca-pos-egy were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Extract PoS Tags

# %%
########################################################################################################################################################################################################################################################################################
def get_segments(ly, l = 512):
    
    S = []  # to store segments
    
    M = len(ly)  # the length of the lyrics
    n_seg = M // l

    l = l - 10 # to account for extra needed to find the next white space
    
    start = 0
    end = M
    
    i = 0
    while i < end:
        #print(i)
        j = i + l
        if j >= end:
            S.append(ly[i:end])
            break
        if ly[j] in [" ", "\n", ".", "\r"]:
            S.append(ly[i:j])
            i = j
            continue
        while j < end:
            if ly[j] in [" ", "\n", ".", "\r"]:
                S.append(ly[i:j])
                i = j
                break
            else:
                j += 1
        if j >= end:
            S.append(ly[i:end])
            break
    
    return S

########################################################################################################################################################################################################################################################################################

def extract_pos_tags():
    """
    Given the lyrics, it returns the PoS tags of all lyrics in the corpus.
    """
    

    Ly = list(lyrics["Lyrics"])
    
    PoS_tags = []
    PoS_scores = []
    
    for i, ly in enumerate(tqdm(Ly)):
        M = len(ly)
        l = 512
        seg = M // l
        T = []
        S = []
        for j in range(seg):
            T = T + pos(ly[j*l : (j+1)*l])
            
        if seg * l <= M:
            T = T + pos(ly[seg*l:])
        S = [d["score"] for d in T]
        T = [d["entity"] for d in T]
        
        PoS_tags.append(T)
        PoS_scores.append(S)
        
        
    return PoS_tags, PoS_scores
########################################################################################################################################################################################################################################################################################

# %%
# Now extract the PoS tags.
T, S = extract_pos_tags()
# Out:
#   0%|          | 0/140 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 100%|██████████| 140/140 [00:07<00:00, 18.13it/s]

# %%
lyrics["PoS Tags"] = T
lyrics["PoS Scores"] = S

# %%
lyrics.sample(30)
# Out:
#                                      Title
# 108        Rabbena Yewaffa2ek - ربنا يوفقك  \
# 25                         Come Back To Me
# 77           Kefaiak A’azar - كفاياك أعذار
# 43              Enta Waheshny - إنت واحشني
# 130                    Ya Aayoon - يا عيون
# 82                      Kol Marra - كل مرة
# 37           Elly Gai Ahla - اللي جاي أحلى
# 15                        Awseflk - أوصفلك
# 24   Betsaab Alaia Nafsy - بتصعب عليا نفسي
# 63               Hases Bekhouf - حاسس بخوف
# 12                Arrab Habiby - قرب حبيبي
# 32               Eish Besho’ak - عيش بشوقك
# 115      Sehiet Ala Sotha - صحيت على صوتها
# 28               Dayman Maak - دايماً معاك
# 138                Ya Waheshny - يا واحشني
# 34                       Ekhteraa - إختراع
# 54          Fagaa Eftaraana - فجأة إفترقنا
# 60             Haeesh Hayati - هاعيش حياتي
# 107               Omry Ebtada - عمري إبتدا
# 78            Khaleek Folazy - خليك فولاذي
# 0                        100 Wesh - ١٠٠ وش
# 119     Taaba Koll El Nas - تاعبة كل الناس
# 131                    Ya Baaeed - يا بعيد
# 86                   Lawel Mara - لأول مرة
# 62                    Harket Dam - حرقة دم
# 100           Mestany El Yom - مستني اليوم
# 97          Mayhonsh Aalaya - مايهونش عليا
# 65               Hayati Fadak - حياتي فداك
# 99         Mehtaglek Ya Ama - محتاجلك ياما
# 58               Forsa Akhira - فرصة أخيرة
#
#                                                 Lyrics
# 108  لا أحكيلك ولا تحكيلي وبلاش تتلككيلي\nمش ناقصة ...  \
# 25   Come back to me\nYeah\nAh, Let me tell you\n\n...
# 77   لو فعلاً بتهمك راحتي زي ما بتقول\nكان المفروض ...
# 43   بتفرج ع الحياة\nوع الأيام وعلى الناس\nإيه شكله...
# 130  ‫\n\nيا قلبي الحظ نادى عليك\nوجابهالك زي ما ال...
# 82   يا عيني يا ليلي يا، يا ليلي\n\nكل مرة بشوفك في...
# 37   السنة دي عدت علينا صعبة، صعبة أوي\nبس المهم إن...
# 15   بتقولي أوصفهالك، أوصفلك\nرقيقة، بريئة زي الموج...
# 24   آه، بتصعب عليا نفسي كل ما أفتكرك\nوتعبي اللي ش...
# 63   حاسس بخوف عمال بيبعد قلبي عنك\nمعرفش ليه مابقت...
# 12   قرب حبيبي، قرب تعالى\nليه سايبني في نار يا حبي...
# 32   لو من تُقل الهم عليك فاض بيك\nلو ليك أي شكوى، ...
# 115  أنا النهاردة صحيت على صوتها\nالله على ده صوت\n...
# 28   دايماً معاك لو في الخيال\nحبيبي وأقرب حد مهما ...
# 138  كل يوم بيفوت عليا\nليك بحن في كل ثانية\nصعب أع...
# 34   معروف أنا من زمان\nولا واحدة بتملالي عينيا\nجا...
# 54   فجأة إفترقنا وفراقنا سرقنا من حضن بعض\nبعد إتف...
# 60   زي ما سهلة عليك تنساني هنساك\nهنساك ولا هرجع ت...
# 107  عمري إبتدا\nمن الليلة دي وياه\nولقيت سبب للحيا...
# 78   ليها طريقة في البواخة الدنيا دي\nلما تصعب حاجة...
# 0    أعزائي الغدارين\nأعزائي الغدارين، اللي غدروا ب...
# 119  أنا شايف دلوقتي قدامي واحدة (قدامي واحدة)\nهيج...
# 131  يا بعيد من بعيد لبعيد\nببعت سلام بالعين قبل ال...
# 86   لأول مرة\nلأول مرة في الحياة\nأشوف قمر بيتكلم\...
# 62   أرجعلك،  أسمعلك\n\nأرجعلك، يعني حرقة دم\nأسمعل...
# 100  مستني اليوم (مستني اليوم)\nمستني اليوم (مستني ...
# 97   مايهونش عليا أسيبك\nمايهونش عليا أنساك\nمايهون...
# 65   أول ما يجي أنا هحلفله\nفي قلبي حبه وهوصفله\nمن...
# 99   هو في كدا في الدنيا\nأقول الآه تسمعها\nأقول ال...
# 58   إديتك فرصة أخيرة عشان تنسيني وما قدرتيش\nإديتك...
#
#                                               PoS Tags
# 108  [part_neg, noun, noun, noun, part_neg, verb, v...  \
# 25   [adj, adv, adj, noun_prop, noun, noun_prop, no...
# 77   [conj_sub, pron, verb, verb, noun, noun, conj_...
# 43   [verb, verb, prep, noun, prep, noun, prep, nou...
# 130  [part_voc, noun, noun, verb, prep, noun_prop, ...
# 82   [part_voc, noun, part_voc, noun, part_voc, pun...
# 37   [noun, pron_dem, verb, prep, adj, punc, adj, a...
# 15   [verb, verb, noun_prop, noun_prop, noun_prop, ...
# 24   [interj, interj, punc, verb, verb, noun, noun,...
# 63   [adj, adj, noun, noun, adj, verb, verb, noun, ...
# 12   [verb, noun, punc, verb, verb, adv_interrog, a...
# 32   [conj_sub, prep, noun, noun, prep, verb, prep,...
# 115  [pron, noun, noun, verb, verb, prep, noun, nou...
# 28   [verb, noun, conj_sub, prep, noun, noun, adj_c...
# 138  [noun_quant, noun, verb, verb, noun, prep, ver...
# 34   [adj, pron, prep, noun, conj, noun, verb, verb...
# 54   [noun, verb, verb, verb, noun, noun, noun, ver...
# 60   [noun, conj_sub, adj, prep, verb, verb, verb, ...
# 107  [noun, verb, verb, verb, prep, noun, pron_dem,...
# 78   [prep, noun, prep, noun, noun, noun, pron_dem,...
# 0    [noun, noun, noun, noun, noun, noun, noun, nou...
# 119  [pron, adj, adv, noun, noun_num, punc, noun, n...
# 131  [part_voc, noun, prep, noun, noun, noun, verb,...
# 86   [adj_num, noun, adj_num, noun, prep, noun, ver...
# 62   [verb, verb, prep, punc, verb, verb, prep, ver...
# 100  [adj, noun, punc, adj, noun, punc, adj, noun, ...
# 97   [verb, verb, verb, prep, noun, verb, verb, nou...
# 65   [adj, conj_sub, verb, pron, verb, verb, prep, ...
# 99   [pron, prep, noun, prep, noun, verb, noun, int...
# 58   [noun, noun, noun, adj, adj, noun, verb, verb,...
#
#                                             PoS Scores
# 108  [0.9992187, 0.55075324, 0.99718934, 0.872182, ...
# 25   [0.65897363, 0.39602605, 0.447428, 0.5382955, ...
# 77   [0.99975425, 0.47693822, 0.99969363, 0.9998248...
# 43   [0.9997758, 0.9998343, 0.9999248, 0.99988675, ...
# 130  [0.9988236, 0.99991894, 0.99995077, 0.9998317,...
# 82   [0.99940765, 0.9990264, 0.99942374, 0.9553836,...
# 37   [0.9999484, 0.99989414, 0.9998876, 0.9999167, ...
# 15   [0.99991953, 0.99949336, 0.9990392, 0.99913895...
# 24   [0.98979014, 0.98079896, 0.99954563, 0.9998261...
# 63   [0.99985015, 0.99971706, 0.9998123, 0.99989057...
# 12   [0.9964121, 0.99994123, 0.9996648, 0.99834883,...
# 32   [0.99978584, 0.9954052, 0.9398228, 0.99990094,...
# 115  [0.99985147, 0.9998529, 0.99992716, 0.99980444...
# 28   [0.9832786, 0.99994993, 0.9993411, 0.99993896,...
# 138  [0.9997563, 0.99981767, 0.99958366, 0.9994272,...
# 34   [0.999688, 0.9999193, 0.99897456, 0.99994504, ...
# 54   [0.99992263, 0.9987457, 0.99239725, 0.923973, ...
# 60   [0.9999467, 0.9834678, 0.9997297, 0.99989235, ...
# 107  [0.99991953, 0.9992304, 0.99905604, 0.9948427,...
# 78   [0.9999474, 0.99994576, 0.9999304, 0.9997899, ...
# 0    [0.9350547, 0.63514787, 0.90886986, 0.9952674,...
# 119  [0.99989355, 0.99930775, 0.99922264, 0.9999199...
# 131  [0.9993255, 0.96834177, 0.9996019, 0.99946207,...
# 86   [0.81427586, 0.99989355, 0.85069406, 0.9999057...
# 62   [0.9959311, 0.93461406, 0.6628554, 0.99942625,...
# 100  [0.9994092, 0.999848, 0.9632232, 0.9992555, 0....
# 97   [0.9994723, 0.9990821, 0.9993623, 0.49173543, ...
# 65   [0.8900833, 0.99946064, 0.9995346, 0.9998988, ...
# 99   [0.99990296, 0.9998714, 0.99937254, 0.99991107...
# 58   [0.98711884, 0.6516214, 0.99993825, 0.9994266,...

# %%
def get_pos_labels():
    """
    Get the set of all possible PoS tags.
    """
    
    tags = []
    
    for t in list(lyrics["PoS Tags"]):
        tags = list(set(tags + t))

    return tags

# %%
tags = get_pos_labels()
print("Number of unique PoS tags: ", len(tags))

print("The set of all unique tags in the corpus are: ", tags)
# Out:
# Number of unique PoS tags:  32
# The set of all unique tags in the corpus are:  ['noun_prop', 'adv', 'pron_rel', 'part_restrict', 'part_neg', 'prep', 'part_det', 'noun_num', 'verb', 'adj', 'adv_interrog', 'adv_rel', 'pron_exclam', 'verb_pseudo', 'noun', 'punc', 'pron_interrog', 'part_interrog', 'part', 'noun_quant', 'adj_comp', 'conj_sub', 'conj', 'part_verb', 'part_voc', 'pron_dem', 'pron', 'adj_num', 'interj', 'part_focus', 'abbrev', 'digit']

# %%
# Example for sanity check.
lyrics["Lyrics"][9][:40]
# Out:
# 'يا حبيبي من حبي فيك\nلا هتكلم ولا أغنيلك\n'

# %%
lyrics["PoS Tags"][9][:10]
# Out:
# ['part_voc',
#  'noun',
#  'prep',
#  'noun',
#  'prep',
#  'part_neg',
#  'verb',
#  'verb',
#  'part_neg',
#  'verb']

# %%
########################################################################################################################################################################################################################################################################################

def extract_feature_for_song(pos_tags, pos_scores):
    """
    Convert the given tags vector into a numerical feature vector weighted by the tags scores.
    """
    
    feature_vector = np.zeros(len(tags))
    
    for k, t in enumerate(tags): # repeat for every tag label
        idx = [i for i, p in enumerate(pos_tags) if p == t] # List comprehension
        feature_vector[k] = sum([pos_scores[i] for i in idx])
        
    return feature_vector

########################################################################################################################################################################################################################################################################################

# %%
extract_feature_for_song(lyrics["PoS Tags"][2], lyrics["PoS Scores"][2])
# Out:
# array([10.58615839,  5.56841332,  9.57552177,  0.        ,  7.47246146,
#        16.38145021,  0.        ,  0.        , 62.39929992,  0.99975222,
#         7.58363569,  0.        ,  0.        ,  2.18944788, 19.91903704,
#         5.48641151,  7.27357554,  0.        ,  0.31709495,  2.99775714,
#         0.        ,  2.67220539,  0.76701272,  0.        ,  5.96325743,
#         0.        ,  2.5638119 ,  0.        , 10.49961078,  0.        ,
#         1.06335971,  0.        ])

# %%
def extract_features_for_corpus():
    """
    Convert PoS tags to numeric feature vectors for all lyrics in
    the songs corpus.
    """
    
    feature_vectors = []
    for _, ly in lyrics.iterrows():
        feature_vectors.append(extract_feature_for_song(ly["PoS Tags"], ly["PoS Scores"]))
        
    lyrics["Feature Vector"] = feature_vectors

# %%
extract_features_for_corpus()

# %%
lyrics.sample(30)
# Out:
#                                                  Title
# 105                               Nour Einy - نور عيني  \
# 73                         Kammel Lewahdak - كمل لوحدك
# 41                             Enta Hayaty - إنت حياتي
# 47                                    Erga3ly - إرجعلي
# 2                     3reft Elly Feha - عرفت اللي فيها
# 100                       Mestany El Yom - مستني اليوم
# 35                        El Hares Allah - الحارس الله
# 119                 Taaba Koll El Nas - تاعبة كل الناس
# 93                            Matesaalnesh - ماتسألنيش
# 50                          Esma W Nassib - قسمة ونصيب
# 108                    Rabbena Yewaffa2ek - ربنا يوفقك
# 27                                        Dayeb - دايب
# 31                 Ehsasy Mabyekdebsh - إحساسي مبيكدبش
# 26                             Dana Baba - ده أنا بابا
# 1                                 180 Darga - ١٨٠ درجة
# 118                             Sweet Melody - يا سلام
# 29                                    E3tezry - إعتذري
# 129                           Ya3ny Khalas - يعني خلاص
# 21   Batelet El Aalam Fel Nakad - بطلة العالم في النكد
# 20                         Bainak W Bainy - بينك وبيني
# 110                             Rayah Balak - ريح بالك
# 57                             Fi Al Haiah - في الحياة
# 43                          Enta Waheshny - إنت واحشني
# 87               Law Hakon Gher Leek - لو هكون غير ليك
# 66                        Hekayat El Hob - حكايات الحب
# 42                             Enta Mesheet - إنت مشيت
# 51                        Etla3 Men Doul - إطلع من دول
# 8                     Alby Elly Habbak - قلبي اللي حبك
# 14                           Awelny Kalam - قولني كلام
# 94                     Matetghairy Baa - ما تتغيري بقى
#
#                                                 Lyrics
# 105  حبيبي تعالى بناديلك، تطمني تريحني\nما تسيبش إي...  \
# 73   ولا هصدق حاجة تقولهالي مهما تعيد وتزيد\nمين ال...
# 41   لو عندي أغلى من عيني يا حبيب عيني\nكنت أشيلك ف...
# 47   حبيبي أنا قلبي واجعني\nإنت عامل فيا إيه؟\nإنت ...
# 2    ‫\n\nعرفت اللي فيها\nعينيه بان عليها\nيا قلبي ...
# 100  مستني اليوم (مستني اليوم)\nمستني اليوم (مستني ...
# 35   (أوه أوه)\n(أوه أوه)\n\nالحارس الله عليك، إيه ...
# 119  أنا شايف دلوقتي قدامي واحدة (قدامي واحدة)\nهيج...
# 93   ما تسألنيش عن العمر اللي كان قبليك\nحبيبي إسأل...
# 50   أيوة كل واحد فينا راح وعاش حب جديد\nبس لسه الخ...
# 108  لا أحكيلك ولا تحكيلي وبلاش تتلككيلي\nمش ناقصة ...
# 27   لأ بقى إستناني محتاجلك\nوشوقي ملاني حبك\nكل يو...
# 31   إحساسي ما بيكدبش نهائي ولا عمره، ولا عمره خيّب...
# 26   مافيش حد أعرفه في كل الناس شافك إلا أما قال\nإ...
# 1    لو راجعة عشان تبعدي بيني وبينها إستني\nدي خدت ...
# 118  She's the type of girl that make your heart be...
# 29   هتموتي وتنسيني\nفاكراني هموت وتجيني\nأصلاً ما ...
# 129  أنا عارف إنك عايز تسيبني\nسيبني وما تجملش الكل...
# 21   مشكلتها بطلة العالم في النكد\nونمرة واحد في ال...
# 20   قولي إيه محبوبي إيه بينك وبيني\nكل ما أجي وأرو...
# 110  ريح بالك وإنسى اللي نسيك\nعيش ليك لياليك\nمش د...
# 57   في الحياة حاجات مهمة بس دايماً في الأهم\nوإنت ...
# 43   بتفرج ع الحياة\nوع الأيام وعلى الناس\nإيه شكله...
# 87   يا حبيبي أنا لو هكون غير ليك\nطب أعيش لمين أنا...
# 66   كام مرة يا حب عليا ناديت\nرحت بأحلامي معاك ومش...
# 42   أنا هنا بناديك فين ألاقيك\nطمني عليك عامل إيه\...
# 51   ليه قولي ليه\nقلبي حب ورق ليه\nوإنت قلبك ليه م...
# 8    قلبي اللي حبك بطل يحبك\nبطل يسلم، بطل يتكلم\nب...
# 14   قولني كلام أول مرة أقوله\nما بقتش أنام الليل ب...
# 94   ما تتغيري بقى حرام عليكي\nهدمتي حياتنا وحبنا\n...
#
#                                               PoS Tags
# 105  [noun, verb, noun, noun, punc, verb, verb, ver...  \
# 73   [conj, verb, verb, noun, verb, prep, conj_sub,...
# 41   [conj_sub, noun, adj_comp, adj_comp, prep, nou...
# 47   [noun, pron, noun, adj, adj, pron, adj, part_v...
# 2    [verb, pron_rel, prep, noun, verb, prep, part_...
# 100  [adj, noun, punc, adj, noun, punc, adj, noun, ...
# 35   [punc, interj, interj, interj, interj, punc, p...
# 119  [pron, adj, adv, noun, noun_num, punc, noun, n...
# 93   [part_neg, verb, verb, prep, noun, pron_rel, v...
# 50   [interj, interj, noun_quant, noun, prep, verb,...
# 108  [part_neg, noun, noun, noun, part_neg, verb, v...
# 27   [interj, adv, adv, noun, noun, pron, adj, prep...
# 31   [noun, noun, part_neg, noun_prop, noun_prop, p...
# 26   [verb, noun, verb, verb, prep, noun_quant, nou...
# 1    [conj_sub, adj, adj, noun, verb, verb, noun, n...
# 118  [noun_prop, noun_prop, punc, noun_prop, noun_p...
# 29   [verb, verb, prep, verb, verb, prep, adj, prep...
# 129  [pron, adj, conj_sub, adj, verb, verb, verb, v...
# 21   [noun, verb, noun, noun, noun, prep, noun, nou...
# 20   [verb, pron_interrog, noun, noun, pron_interro...
# 110  [verb, noun, verb, verb, pron_rel, verb, verb,...
# 57   [prep, noun, noun, adj, conj, verb, prep, adj_...
# 43   [verb, verb, prep, noun, prep, noun, prep, nou...
# 87   [part_voc, noun, pron, conj_sub, verb, verb, n...
# 66   [noun_quant, noun, part_voc, noun, noun_prop, ...
# 42   [pron, adv, verb, noun, adv_interrog, verb, ve...
# 51   [adv_interrog, verb, adv_interrog, noun, verb,...
# 8    [noun, pron_rel, noun, noun, verb, noun, verb,...
# 14   [verb, verb, noun, adj, noun, verb, verb, part...
# 94   [part_neg, verb, verb, adv, adv, noun, prep, v...
#
#                                             PoS Scores
# 105  [0.9999026, 0.9998971, 0.99657696, 0.9920739, ...  \
# 73   [0.9907651, 0.9998952, 0.9998499, 0.9999521, 0...
# 41   [0.99972457, 0.999915, 0.9992907, 0.99907434, ...
# 47   [0.9999473, 0.9999049, 0.9999441, 0.999567, 0....
# 2    [0.9999306, 0.9998599, 0.99991214, 0.99991477,...
# 100  [0.9994092, 0.999848, 0.9632232, 0.9992555, 0....
# 35   [0.9837906, 0.9914751, 0.9931885, 0.99164164, ...
# 119  [0.99989355, 0.99930775, 0.99922264, 0.9999199...
# 93   [0.9860935, 0.9979747, 0.9983386, 0.9999243, 0...
# 50   [0.9984931, 0.9970897, 0.9998061, 0.9669135, 0...
# 108  [0.9992187, 0.55075324, 0.99718934, 0.872182, ...
# 27   [0.99865013, 0.9954526, 0.9943731, 0.9997563, ...
# 31   [0.99509346, 0.9967996, 0.99966323, 0.9358765,...
# 26   [0.99988735, 0.9999324, 0.9998394, 0.9978927, ...
# 1    [0.9995258, 0.9998461, 0.9997545, 0.9999523, 0...
# 118  [0.9480098, 0.8263456, 0.48524612, 0.84463066,...
# 29   [0.9999254, 0.99991846, 0.5175396, 0.9999242, ...
# 129  [0.999858, 0.99986625, 0.99966705, 0.99986863,...
# 21   [0.998379, 0.9947925, 0.99985087, 0.9999081, 0...
# 20   [0.9998926, 0.79953533, 0.91797924, 0.9847121,...
# 110  [0.9884123, 0.9999194, 0.9998671, 0.9997409, 0...
# 57   [0.99994874, 0.9998118, 0.99995697, 0.99977964...
# 43   [0.9997758, 0.9998343, 0.9999248, 0.99988675, ...
# 87   [0.9990281, 0.9999031, 0.9999137, 0.9997291, 0...
# 66   [0.99522275, 0.999954, 0.9994836, 0.998803, 0....
# 42   [0.9998925, 0.9994936, 0.76227075, 0.8242091, ...
# 51   [0.9641538, 0.9999049, 0.96111345, 0.99986124,...
# 8    [0.9998971, 0.9998691, 0.9516614, 0.992073, 0....
# 14   [0.9999281, 0.9996885, 0.9999206, 0.7892322, 0...
# 94   [0.9787106, 0.9989229, 0.9559421, 0.9992822, 0...
#
#                                         Feature Vector
# 105  [11.437098264694214, 0.0, 1.7153308391571045, ...
# 73   [18.944804251194, 1.9982765316963196, 9.822017...
# 41   [8.681499779224396, 0.877665102481842, 0.0, 0....
# 47   [5.539377152919769, 0.0, 0.9998347759246826, 0...
# 2    [10.586158394813538, 5.568413317203522, 9.5755...
# 100  [1.8252708613872528, 3.3343025743961334, 1.999...
# 35   [22.72800576686859, 0.9607675969600677, 28.592...
# 119  [7.55018013715744, 7.592191517353058, 5.999152...
# 93   [1.2933191657066345, 2.487399786710739, 1.9997...
# 50   [0.0, 1.9988643527030945, 6.997969686985016, 0...
# 108  [6.960751533508301, 1.9938181638717651, 3.2535...
# 27   [28.392396986484528, 8.939660847187042, 2.9996...
# 31   [4.9136112332344055, 6.981593549251556, 4.9992...
# 26   [6.755359590053558, 1.9977598190307617, 1.9987...
# 1    [2.9871203303337097, 0.999453604221344, 4.9993...
# 118  [303.28173300623894, 10.475770384073257, 0.0, ...
# 29   [1.9757431149482727, 1.5318295359611511, 4.982...
# 129  [4.851715832948685, 0.0, 3.9995083808898926, 0...
# 21   [0.0, 1.9897907376289368, 4.998850762844086, 0...
# 20   [14.454560935497284, 0.2747677266597748, 0.0, ...
# 110  [0.4002353549003601, 0.0, 4.999311029911041, 0...
# 57   [3.6311569213867188, 0.0, 1.8861531615257263, ...
# 43   [2.41628959774971, 0.0, 0.0, 0.0, 5.6412410140...
# 87   [1.9957066774368286, 0.0, 1.9996828436851501, ...
# 66   [4.780009388923645, 1.976660668849945, 0.99984...
# 42   [1.6082456707954407, 5.996585965156555, 0.0, 0...
# 51   [25.11480003595352, 0.9995906949043274, 0.9998...
# 8    [3.4683135747909546, 2.622891843318939, 6.9989...
# 14   [5.35374915599823, 0.0, 17.80248910188675, 0.0...
# 94   [16.461368203163147, 17.932849884033203, 4.999...

# %% [markdown]
# # Clustering

# %%
M = len(lyrics)
N = len(tags)

feature_matrix = np.zeros((M, N))

print(feature_matrix.shape)
# Out:
# (140, 32)

# %%
features = list(lyrics["Feature Vector"])
print(len(features))
print(features[67])
# Out:
# 140
# [ 5.74678019  0.          0.999861    0.          0.          5.71020955
#   0.         13.97671032 40.72471833  4.33167049  1.98666716  0.
#   0.          3.27624395 97.63223127  2.99837971  0.          0.
#   0.56249636  0.          0.99900788  0.          0.94514757  0.
#   3.99548268  2.53243023 11.4765197   0.          0.          0.
#   0.          0.        ]

# %%
for i, f in enumerate(features):
    for j in range(len(tags)):
        feature_matrix[i,j] = f[j]

# %%
feature_matrix.shape
# Out:
# (140, 32)

# %%
feature_matrix[10,:].shape
# Out:
# (32,)

# %%
# Check for correctness of the previous construction of the feature matrix.

assert np.array_equiv(feature_matrix[10,:], features[10])

# %%
assert np.array_equiv(feature_matrix[67,:], features[67])

# %%
assert np.array_equiv(feature_matrix[100,:], features[100])

# %%
lyrics.sample(30)
# Out:
#                                                Title
# 84             Kol Yom Ahebo Tani - كل يوم أحبه تاني  \
# 28                         Dayman Maak - دايماً معاك
# 86                             Lawel Mara - لأول مرة
# 11                     Ana Wala 3aref - أنا ولا عارف
# 2                   3reft Elly Feha - عرفت اللي فيها
# 112                             Rouh Alby - روح قلبي
# 9             Allah Yebarekly Fek - الله يباركلي فيك
# 132                     Ya Bent El Eh - يا بنت الإيه
# 91               Mahadesh Hases Beya - محدش حاسس بيا
# 27                                      Dayeb - دايب
# 54                    Fagaa Eftaraana - فجأة إفترقنا
# 131                              Ya Baaeed - يا بعيد
# 14                         Awelny Kalam - قولني كلام
# 85               Lama Betkon Ba’eid - لما بتكون بعيد
# 42                           Enta Mesheet - إنت مشيت
# 82                                Kol Marra - كل مرة
# 139                           Zai Al Nile - زي النيل
# 93                          Matesaalnesh - ماتسألنيش
# 7                                  Akalemha - أكلمها
# 94                   Matetghairy Baa - ما تتغيري بقى
# 46   Erfet Teghayar Men Nafsaha - عرفت تغير من نفسها
# 36                     Elly Aada Aada - اللي عدى عدى
# 45              Enty Nesity Nafsek - إنتي نسيتي نفسك
# 134                     Ya Mali Aaeny - يا مالي عيني
# 1                               180 Darga - ١٨٠ درجة
# 89                       Lolaak Habibi - لولاك حبيبي
# 17                    Ba3eed 3an 3eny - بعيد عن عيني
# 117                                    Soutek - صوتك
# 122                                 Teaarafy - تعرفي
# 23                   Bekelma Netsaleh - بكلمة نتصالح
#
#                                                 Lyrics
# 84   كل يوم أحبه تاني\nآه من اللي هيجرالي\n\nكل يوم...  \
# 28   دايماً معاك لو في الخيال\nحبيبي وأقرب حد مهما ...
# 86   لأول مرة\nلأول مرة في الحياة\nأشوف قمر بيتكلم\...
# 11   أنا ولا عارف أنا مالي ولا إيه اللي جرالي، بحبك...
# 2    ‫\n\nعرفت اللي فيها\nعينيه بان عليها\nيا قلبي ...
# 112  روح قلبي أنا وعدتك وصدقني هكون وياك\nوعليك أبي...
# 9    يا حبيبي من حبي فيك\nلا هتكلم ولا أغنيلك\nمن ا...
# 132  لا لا-لا-لا لا\nلا لا-لا-لا لا\nلا لا-لا-لا لا...
# 91   ما حدش عارف حاجة، ما حدش حاسس بيا\nأيوة ببقى ف...
# 27   لأ بقى إستناني محتاجلك\nوشوقي ملاني حبك\nكل يو...
# 54   فجأة إفترقنا وفراقنا سرقنا من حضن بعض\nبعد إتف...
# 131  يا بعيد من بعيد لبعيد\nببعت سلام بالعين قبل ال...
# 14   قولني كلام أول مرة أقوله\nما بقتش أنام الليل ب...
# 85   لما بتكون بعيد بحضر كلام أقوله\nوأما بتكون قري...
# 42   أنا هنا بناديك فين ألاقيك\nطمني عليك عامل إيه\...
# 82   يا عيني يا ليلي يا، يا ليلي\n\nكل مرة بشوفك في...
# 139  هي جت عليه ماهي بايظة من كله\nيسبني يبيعني ولا...
# 93   ما تسألنيش عن العمر اللي كان قبليك\nحبيبي إسأل...
# 7    أكلمها، مابترودش عشان أقلق\nوبعد شويه أكلمها و...
# 94   ما تتغيري بقى حرام عليكي\nهدمتي حياتنا وحبنا\n...
# 46   آه ومش قادر ما أقولهاش\n\nعرفت تغير من نفسها\n...
# 36   لا مش هعيش غير بيك أنا لا\nقولي إيه يرضيك ها ب...
# 45   إنتي نسيتي نفسك وبقيتي بتجرحيني\nزمان كان بس ن...
# 134  ‫\n\nيا مالي عيني\nيا مالي عيني\n\nحياتي واقفة...
# 1    لو راجعة عشان تبعدي بيني وبينها إستني\nدي خدت ...
# 89   أحبك تاني إيه\nأكتر من الحب دا كله إيه\nخلصت أ...
# 17   بعيد عن عيني جايز\nبس اللي بيني وبينه عايش\nجو...
# 117  ‫\n\nصوتك متغير كده ليه؟\nفي حد جنبك ولا إيه؟\...
# 122  تعرفي بحلم إيه دلوقتي، تعرفي بحلم إيه؟\nبحلم ي...
# 23   بكلمة نتصالح وبكلمتين نرجع\nلو حتى إيه يمنع، م...
#
#                                               PoS Tags
# 84   [noun_quant, noun, verb, verb, adj, interj, in...  \
# 28   [verb, noun, conj_sub, prep, noun, noun, adj_c...
# 86   [adj_num, noun, adj_num, noun, prep, noun, ver...
# 11   [pron, conj, adj, pron, noun, conj, pron_inter...
# 2    [verb, pron_rel, prep, noun, verb, prep, part_...
# 112  [verb, noun, pron, verb, noun, verb, noun, ver...
# 9    [part_voc, noun, prep, noun, prep, part_neg, v...
# 132  [interj, interj, punc, interj, punc, interj, i...
# 91   [part_neg, verb, part_neg, adj, noun, punc, pa...
# 27   [interj, adv, adv, noun, noun, pron, adj, prep...
# 54   [noun, verb, verb, verb, noun, noun, noun, ver...
# 131  [part_voc, noun, prep, noun, noun, noun, verb,...
# 14   [verb, verb, noun, adj, noun, verb, verb, part...
# 85   [conj_sub, verb, noun, noun, noun, noun, verb,...
# 42   [pron, adv, verb, noun, adv_interrog, verb, ve...
# 82   [part_voc, noun, part_voc, noun, part_voc, pun...
# 139  [pron, verb, prep, adj, adj, adj, prep, noun_q...
# 93   [part_neg, verb, verb, prep, noun, pron_rel, v...
# 7    [verb, verb, punc, noun_prop, noun_prop, noun_...
# 94   [part_neg, verb, verb, adv, adv, noun, prep, v...
# 46   [interj, interj, part_neg, adj, part_neg, verb...
# 36   [part_neg, part_neg, verb, verb, noun, prep, p...
# 45   [pron, pron, verb, verb, noun, verb, pron, ver...
# 134  [part_voc, noun, noun, part_voc, noun, noun, n...
# 1    [conj_sub, adj, adj, noun, verb, verb, noun, n...
# 89   [verb, verb, adj, pron_interrog, adj_comp, adj...
# 17   [adj, prep, noun, adj, adj, conj, pron_rel, no...
# 117  [noun, adj, adj, noun, adv_interrog, punc, pre...
# 122  [verb, verb, noun, noun, pron_exclam, adv, pun...
# 23   [noun, verb, verb, noun, noun, verb, conj_sub,...
#
#                                             PoS Scores
# 84   [0.99980503, 0.9998803, 0.99978036, 0.9929819,...  \
# 28   [0.9832786, 0.99994993, 0.9993411, 0.99993896,...
# 86   [0.81427586, 0.99989355, 0.85069406, 0.9999057...
# 11   [0.999918, 0.97232777, 0.99916327, 0.99991477,...
# 2    [0.9999306, 0.9998599, 0.99991214, 0.99991477,...
# 112  [0.9990646, 0.9998934, 0.99988914, 0.99925524,...
# 9    [0.999474, 0.9999286, 0.9986525, 0.9972995, 0....
# 132  [0.99899966, 0.9989334, 0.9998728, 0.99886876,...
# 91   [0.99870455, 0.9997106, 0.954056, 0.99967015, ...
# 27   [0.99865013, 0.9954526, 0.9943731, 0.9997563, ...
# 54   [0.99992263, 0.9987457, 0.99239725, 0.923973, ...
# 131  [0.9993255, 0.96834177, 0.9996019, 0.99946207,...
# 14   [0.9999281, 0.9996885, 0.9999206, 0.7892322, 0...
# 85   [0.9994178, 0.99969697, 0.8023392, 0.99855345,...
# 42   [0.9998925, 0.9994936, 0.76227075, 0.8242091, ...
# 82   [0.99940765, 0.9990264, 0.99942374, 0.9553836,...
# 139  [0.99990153, 0.999858, 0.99992085, 0.6283356, ...
# 93   [0.9860935, 0.9979747, 0.9983386, 0.9999243, 0...
# 7    [0.99988854, 0.99983716, 0.9996631, 0.7135158,...
# 94   [0.9787106, 0.9989229, 0.9559421, 0.9992822, 0...
# 46   [0.9939412, 0.99176675, 0.99984384, 0.99987054...
# 36   [0.98249876, 0.99989104, 0.9999031, 0.9998883,...
# 45   [0.99990726, 0.9999033, 0.9998956, 0.99448264,...
# 134  [0.99921453, 0.9259773, 0.99991524, 0.99924135...
# 1    [0.9995258, 0.9998461, 0.9997545, 0.9999523, 0...
# 89   [0.99982506, 0.49489373, 0.9983602, 0.9076027,...
# 17   [0.96584266, 0.99988997, 0.9998543, 0.9997261,...
# 117  [0.9999126, 0.99982977, 0.99981815, 0.57139266...
# 122  [0.99989796, 0.8813294, 0.9999348, 0.99991286,...
# 23   [0.9998903, 0.9998455, 0.9997762, 0.9995529, 0...
#
#                                         Feature Vector
# 84   [14.57748407125473, 4.164320379495621, 15.9976...
# 28   [11.789936423301697, 0.0, 5.61979752779007, 0....
# 86   [7.3450718224048615, 7.995153546333313, 8.9587...
# 11   [6.629074573516846, 6.811905533075333, 6.99883...
# 2    [10.586158394813538, 5.568413317203522, 9.5755...
# 112  [4.155067592859268, 1.5411073565483093, 3.9993...
# 9    [42.60688918828964, 0.0, 0.0, 0.0, 3.974081933...
# 132  [86.99128425121307, 0.0, 1.999595046043396, 0....
# 91   [3.324031800031662, 0.0, 1.9996849298477173, 0...
# 27   [28.392396986484528, 8.939660847187042, 2.9996...
# 54   [6.654327303171158, 7.990696132183075, 2.99953...
# 131  [7.173882961273193, 5.996724963188171, 0.0, 0....
# 14   [5.35374915599823, 0.0, 17.80248910188675, 0.0...
# 85   [7.626737058162689, 0.0, 6.998863458633423, 0....
# 42   [1.6082456707954407, 5.996585965156555, 0.0, 0...
# 82   [0.0, 0.0, 0.0, 3.9698818922042847, 0.0, 4.551...
# 139  [7.167575240135193, 3.7259002923965454, 6.9990...
# 93   [1.2933191657066345, 2.487399786710739, 1.9997...
# 7    [20.840922325849533, 0.0, 2.999652862548828, 0...
# 94   [16.461368203163147, 17.932849884033203, 4.999...
# 46   [121.2719307988882, 7.798876762390137, 2.99959...
# 36   [0.0, 7.383804261684418, 3.99909508228302, 0.0...
# 45   [1.9401187300682068, 11.381298780441284, 6.840...
# 134  [0.9998683929443359, 1.9987866282463074, 4.999...
# 1    [2.9871203303337097, 0.999453604221344, 4.9993...
# 89   [23.273727595806122, 0.0, 0.0, 0.0, 3.99697357...
# 17   [6.286005824804306, 0.9991612434387207, 5.3049...
# 117  [1.1592516899108887, 0.0, 5.11912739276886, 0....
# 122  [0.7823717594146729, 1.9987710118293762, 0.0, ...
# 23   [8.336525440216064, 0.0, 5.58721798658371, 0.0...

# %%
feature_matrix[-25,:]
# Out:
# array([ 9.07351488,  4.9958753 , 10.99849713,  0.        , 10.79624361,
#        19.28489378,  0.        ,  0.        , 87.54501909, 59.27302307,
#         0.        ,  0.        ,  0.        ,  0.        , 69.38739794,
#         0.        ,  0.        ,  0.        ,  0.        ,  2.99287754,
#         0.        ,  3.48387605,  5.34500805,  0.        ,  1.99847722,
#        11.87499428, 15.99834919,  0.        ,  7.90481305,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# **Standardization**: Standardization scales, or shifts, the values for each numerical feature in the dataset so that the features have a mean of 0 and standard deviation of 1:

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
#from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

scaler = StandardScaler()
scaled_feature_matrix = scaler.fit_transform(feature_matrix)

scaled_feature_matrix
# Out:
# array([[-0.0847601 ,  0.73728481,  1.86582751, ..., -0.38055567,
#         -0.23888858, -0.15774   ],
#        [-0.27581249, -0.46421741,  0.2048675 , ..., -0.38055567,
#         -0.23888858,  9.33210266],
#        [-0.14744139,  0.63812655,  1.2908572 , ..., -0.38055567,
#          1.25677906, -0.15774   ],
#        ...,
#        [-0.25045286,  5.74380088, -0.50700817, ..., -0.38055567,
#         -0.23888858, -0.15774   ],
#        [-0.25394578,  0.4981751 , -0.98153742, ..., -0.38055567,
#         -0.23888858, -0.15774   ],
#        [-0.20519176,  0.19358704,  0.67942298, ..., -0.38055567,
#         -0.23888858, -0.15774   ]])

# %% [markdown]
# We will apply the kmeams clustering method. But first we want to find the optimal numbr of clusters. For this we use two criteria: (1) the Elbow curve method and (2) Silhouette Analysis.
#
# We start with the Elbow curve method.
#
# ## Elbow method
#
# It is the most popular method for determining the optimal number of clusters. The method is based on calculating the Within-Cluster-Sum of Squared Errors (WSS) for different number of clusters (k) and selecting the k for which change in WSS first starts to diminish.
# The idea behind the elbow method is that the explained variation changes rapidly for a small number of clusters and then it slows down leading to an elbow formation in the curve. The elbow point is the number of clusters we can use for our clustering algorithm. Further details on this method can be found in this paper by Chunhui Yuan and Haitao Yang [https://www.mdpi.com/2571-8800/2/2/16/pdf].
#
# We will use the YellowBrick library for visualization and determination of the best value for the number of clusters $k$. It is a wrapper around Scikit-Learn.

# %%
# !pip3 install yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\python\lib\site-packages (from yellowbrick) (3.7.1)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy>=1.0.0 in c:\python\lib\site-packages (from yellowbrick) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\python\lib\site-packages (from yellowbrick) (1.3.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\python\lib\site-packages (from yellowbrick) (1.24.2)
# Requirement already satisfied: cycler>=0.10.0 in c:\python\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (5.12.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\python\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.2.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\python\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\python\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#    -------------------------------------- 282.6/282.6 kB 791.8 kB/s eta 0:00:00
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5

# %%
from yellowbrick.cluster import KElbowVisualizer

# %%
model = KMeans(
  init = "random",
  n_init = 30,
  max_iter = 1000
)

# k is range of number of clusters.
visualizer = KElbowVisualizer(
  model, 
  k = (2,30), # range for the possible number of clusters
  timings = True
)

visualizer.fit(scaled_feature_matrix)        # Fit data to visualizer

visualizer.show(outpath = "./elbow_figure.png");        # Finalize and render figure
#savefig("./figs/elbow_figure.png", dpi = "figure");

# %% [markdown]
# The elbow method is run for several times. The obtained number of cluster generally varies between $10$ and $20$, however, concentrated around $15$. So, we take $k=15$ as the optimal number of clusters induced by the elbow method. We now apply another more rigorous method.

# %% [markdown]
# ## Silhouette Coefficient
#
# The **Silhouette Coefficient** for a point $i$ is defined as follows:
#
# $$S(i) = \frac{b(i) - a(i)}{\max(a(i),b(i))}$$
#
# where $b(i)$ is the smallest average distance of point $i$ to all points in any other cluster and $a(i)$ is the average distance of $i$ from all other points in its cluster.
# For example, if we have only 3 clusters A,B and C and $i$ belongs to cluster C, then $b(i)$ is calculated by measuring the average distance of $i$ from every point in cluster A, the average distance of $i$ from every point in cluster B and taking the smallest resulting value. The **Silhouette Coefficient** for the dataset is the average of the Silhouette Coefficient of individual points.
#
# The Silhouette Coefficient tells us if individual points are correctly assigned to their clusters. We can use the following thumb rules while using Silhouette Coefficient:
# $S(i)$ close to $0$ means that the point is between two clusters
# If it is closer to $-1$, then we would be better off assigning it to the other clusters
# If $S(i)$ is close to 1, then the point belongs to the ‘correct’ cluster
# For more details on this method, please refer to this 2018 paper by N. Kaoungku, K. Suksut , R. Chanklan and K. Kerdprasop (https://www.researchgate.net/publication/323588077_The_silhouette_width_criterion_for_clustering_and_association_mining_to_select_image_features). We will be using the KElbowVisualizer function to implement Silhouette Coefficient for K-means clustering algorithm:

# %%
model = KMeans(
  #init = "random",
  n_init = 30,
  max_iter = 1000
)

# k is range of number of clusters.
visualizer = KElbowVisualizer(
  model, 
  k = (2,30), # range for the possible number of clusters
  metric = "silhouette",
  timings = True
)

visualizer.fit(scaled_feature_matrix);        # Fit data to visualizer

visualizer.show("./silhouette_figure.png");        # Finalize and render figure

# %% [markdown]
# We have run the previous experiment several times and it always give the same result that the optimal number of clusters (according to the silhouette coefficient) is $k=2$. As the silhouette coefficient criterion is more reliable than the elbow method which is mostly vague as the elbow does not appear clear in the figure, we stick to the former method and take the number of clusters to be just $k=2$. This means that the lyrics of Shadia can only be categorized into two clusters based on the PoS tagging of the lyrics.

# %%
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

model = KMeans(
    2,
    n_init = 30
)
visualizer = SilhouetteVisualizer(model)

visualizer.fit(
    scaled_feature_matrix,
)

visualizer.poof()
# visualizer.show()
# Out:
# <Axes: title={'center': 'Silhouette Plot of KMeans Clustering for 140 Samples in 2 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
no_clusts = 2

C = KMeans(
    init = "random",
    n_clusters = no_clusts,
    n_init = 10,
    max_iter=1000,
)

C.fit(scaled_feature_matrix)
# Out:
# KMeans(init='random', max_iter=1000, n_clusters=2, n_init=10)

# %%
N = len(lyrics)

c0 = [i for i in range(N) if C.labels_[i] == 0]
c1 = [i for i in range(N) if C.labels_[i] == 1]

y = [0] * N
for i in range(N):
    if i in c1:
        y[i] = 1

# %%
c1[:10]
# Out:
# [1, 2, 3, 4, 5, 7, 8, 9, 13, 15]

# %%
print(y[:10])
# Out:
# [0, 1, 1, 1, 1, 1, 0, 1, 1, 1]

# %% [markdown]
# In the following we draw the first two components of applying the pca, with the points color-coded by the corresponding cluster to which it belongs.

# %%
from yellowbrick.features.pca import PCADecomposition

visualizer = PCADecomposition(scale=True, center=False, col = y)
visualizer.fit_transform(scaled_feature_matrix, y)
visualizer.poof()
# Out:
# <Axes: title={'center': 'Principal Component Plot'}, xlabel='$PC_1$', ylabel='$PC_2$'>

# %% [markdown]
# As shown the two cluster are very closed and not very well separated. That explains the above figure where the silhouette score is realtively low $0.326$. Inn addition, the precieding silhouette plot goes with negative scores till $-0.4$. So, from the perspective of PoS tagging the lyrics of Shadia are moderately diverse regarding the lingusitic structures. It is also apparent that the blue larger cluster is very much focused, unlike the second cluster which is reltively dispersed. So, this can be viewed that all of Shadia's songs are similar (wrt the PoS lingusitic structure), with some anomalies that constitute the second cluster.

# %%
print("Number of songs in the first cluster: ", len(c0))
print("Number of songs in the second cluster: ", len(c1))
# Out:
# Number of songs in the first cluster:  55
# Number of songs in the second cluster:  85

# %%
s0 = [list(lyrics["Title"])[i] for i in range(N) if i in c0]
s1 = [list(lyrics["Title"])[i] for i in range(N) if i in c1]

# %%
import random

print("Sample songs in the first cluster (the larger blue cluster): ")
random.sample(s0, 15)
# Out:
# Sample songs in the first cluster (the larger blue cluster):
# ['Sweet Melody - يا سلام',
#  'Makontesh Mebayen - ماكنتش مبين',
#  'Fagaa Eftaraana - فجأة إفترقنا',
#  'Ain Shams - عين شمس',
#  'Sehiet Ala Sotha - صحيت على صوتها',
#  'Enta Waheshny - إنت واحشني',
#  'Kammel Lewahdak - كمل لوحدك',
#  'Arrab Habiby - قرب حبيبي',
#  'Etmany - إطمني',
#  'Eish Besho’ak - عيش بشوقك',
#  'Kol Dah Ala Aieh - كل ده على إيه',
#  'Khontek Embareh - خنتك إمبارح',
#  'Come Back To Me',
#  'Ba3eesh - بعيش',
#  'Taaba Koll El Nas - تاعبة كل الناس']

# %%
print("Sample songs in the second cluster (the smaller green cluster): ")
random.sample(s1, 15)
# Out:
# Sample songs in the second cluster (the smaller green cluster):
# ['Nafs El Nehaya - نفس النهاية',
#  'Erga3ly - إرجعلي',
#  'Enta Mesheet - إنت مشيت',
#  'Ya Habibi Shoof - يا حبيبي شوف',
#  'Ayam Zaman - أيام زمان',
#  'Haeesh Hayati - هاعيش حياتي',
#  'Nergaa Tani - نرجع تاني',
#  'Enta Hayaty - إنت حياتي',
#  'Lolaak Habibi - لولاك حبيبي',
#  'Kol Sana Wenta Tayeb - كل سنة وإنت طيب',
#  'Seeb El Hob - سيب الحب',
#  'W Ahlam Leeh - وأحلم ليه',
#  'Enaya Bethebbak - عينيا بتحبك',
#  'Rabbena Yewaffa2ek - ربنا يوفقك',
#  'Teaarafy - تعرفي']
